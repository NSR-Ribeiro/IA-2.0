# %% [markdown]
# "Minha vovó Cecilia Lima (in memoriam) sempre dizia:"
# - Esse computador só falta falar.

# %% [markdown]
# # PLN - Processamento de Lingagem Neural

# %% [markdown]
# - Engenheiro de IA (vocês)
# - Texto (Dados não Estruturados) - EDA
# - Data Mining (Text Mining) - TDM
# - Onde Minerar:
# - Emails
# - Transcrições
# - Artigos
# - SMSs
# - Medias sociais
# - DIário de Bordo
# - Livros
#
# - Desafios
# - TRansformar texto em voz
# - Transformar voz em texto
# - Feature Engineering: Texto em dados Númericos.

# %% [markdown]
# - Natural Language Toolkit? = Corpus (texto que será minerado)
# - Conjunto de Corpus: Corpora
# - Conjunto de Corpus: Corpora
#
# A biblioteca NLTK - ferramentas para trabalhar com texto, além de corpora de texto em diversos idiomas.

# %% [markdown]
# - Analisar sentimentos
# - Nuvem de Palavras

# %% [markdown]
# ![image.png](attachment:image.png)
