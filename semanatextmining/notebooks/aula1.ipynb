# %%
print('Alô Mundo IA!!')
# Out:
# Alô Mundo IA!!

# %% [markdown]
# # Introdução e Inteligência Artificial
#
# Entender a inteligência artificial, além das ferramentas tem suas vantagens:
#
# - Você pode aprender a criar suas próprias soluções
# - Criar startups e empresas inovadoras
# - Pode apresentar as soluções prontas com autoridade
# - Pode utilizar-se de modelos pré-treinados
# - Preparar o currículo para novos empregos e oportunidades
# - Se atualizar de novos recursos tecnológicos

# %% [markdown]
# # Física
#
# - IA para encapsular funções e aumentar o processamento de dados

# %% [markdown]
# # Jogos
#
# - Dota-2 OpenAi 5 máquina contra 5 jogadores profissionais

# %%
! pip install pandas
# Out:
# ...
#   Using cached pandas-2.2.2-cp312-cp312-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached numpy-2.1.1-cp312-cp312-win_amd64.whl.metadata (59 kB)
# ...
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-2.2.2-cp312-cp312-win_amd64.whl (11.5 MB)
# Using cached numpy-2.1.1-cp312-cp312-win_amd64.whl (12.6 MB)
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# ...

# %%
# Importar o pandas
import pandas as pd

# %%
# URL o dataset Iris
url = 'https://gist.githubusercontent.com/netj/8836201/raw/6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv'

# %%
# Carregar o Dataset
df = pd.read_csv(url)

# %%
print(type(url))
# Out:
# <class 'str'>

# %%
# mostrar 
df.head(2)
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa

# %%
# mostrando a variedade de palntas
df['variety'].value_counts()
# Out:
# variety
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: count, dtype: int64

# %% [markdown]
# # List Comprehension

# %%
# Aplicação do List Comprehension
# [] - Lista
# string --> s
# Trocar o '.' por '_', boa pratica para não bugar algumas funções
df.columns = [s.replace('.', '_') for s in df.columns]

# %%
df.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa

# %%
# Pesquisa
# copia independente (copy()) - as alterações não afetam o df original

df_setosa = df.query('variety == "Setosa"').copy()
df_virginica = df.query('variety == "Virginica"').copy()
df_versicolor = df.query('variety == "Versicolor"').copy()

# criar uma lista dos nomes das colunas de medidas
medidas = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']

# %%
! pip install matplotlib
# Out:
# ...
#   Using cached matplotlib-3.9.2-cp312-cp312-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached contourpy-1.3.0-cp312-cp312-win_amd64.whl.metadata (5.4 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.53.1-cp312-cp312-win_amd64.whl.metadata (165 kB)
# ...
#   Using cached pillow-10.4.0-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# ...
#   Using cached pyparsing-3.1.4-py3-none-any.whl.metadata (5.1 kB)
# ...
# Using cached matplotlib-3.9.2-cp312-cp312-win_amd64.whl (7.8 MB)
# Using cached contourpy-1.3.0-cp312-cp312-win_amd64.whl (218 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.53.1-cp312-cp312-win_amd64.whl (2.2 MB)
# ...
# Using cached pillow-10.4.0-cp312-cp312-win_amd64.whl (2.6 MB)
# Using cached pyparsing-3.1.4-py3-none-any.whl (104 kB)
# ...

# %%
# usando panda para criar um gráfico

df_setosa[medidas].hist()
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
df_virginica[medidas].hist()
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
df_versicolor[medidas].hist()
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %% [markdown]
# # Poder Preditivo

# %%
df.query('petal_length > 5')['variety'].value_counts()
# Out:
# variety
# Virginica     41
# Versicolor     1
# Name: count, dtype: int64

# %%
df.query('petal_length > 5')['variety'].hist()
# Out:
# <Axes: >

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Inteligencia Artificial

# %% [markdown]
# - Máquna que imitam comportamentos humanos (seres vivos)
# - Esse conceito é geral (guarda-chuva)
# - Máquinas e softqueres que tomam decisões e podem prever o futuro.
# - Máquina inteligentes que podem executar desde taredas simples de automação até vencer um humano em uma partida de xadrez.

# %% [markdown]
# # Aprendizado de Máquina
#
# -  Machine Learnig
# - Área dentro da IA
# - Pode ser visto como uma área dentro da inteligencia artificial
# e se refere a técnicas para construir conhecimento (estima funções) a partir de observações (0, 1) - variáveis explicaticas, variável target(alvo).

# %% [markdown]
# # Aprendizado Profundo
#
# - Redes Neurais
# - Deep Learning
# - Neurociência

# %% [markdown]
# ![Captura de tela 2024-09-10 111348.png](<attachment:Captura de tela 2024-09-10 111348.png>)
